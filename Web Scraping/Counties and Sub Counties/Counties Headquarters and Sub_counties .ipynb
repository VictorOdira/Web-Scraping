# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = "https://afrocave.com/list-of-counties/"
response = requests.get(url)
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    title = soup.title.text
    print(f"Page Title: {title}")
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# Page Title: List of Counties and Sub-Counties in Kenya

# %%
table = soup.find('table')
rows = table.find_all('tr')

# Extracting column headers
columns = []
for col in rows[0].find_all('th'):
    columns.append(col.text.strip())

# Extracting data rows
data = []
for row in rows[1:]:
    row_data = []
    for col in row.find_all('td'):
        row_data.append(col.text.strip())
    data.append(row_data)

# Create a Pandas DataFrame
df = pd.DataFrame(data, columns=columns)

# Display the DataFrame
df
# Out:
#    Code           County    Headquarters  \
# 0    30          Baringo        Kabarnet
# 1    36            Bomet           Bomet
# 2    39          Bungoma         Bungoma
# 3    40            Busia           Busia
# 4    28  Elgeyo-Marakwet            Iten
# 5    14             Embu            Embu
# 6     7          Garissa         Garissa
# 7    43         Homa Bay        Homa Bay
# 8    11           Isiolo          Isiolo
# 9    34          Kajiado         Kajiado
# 10   37         Kakamega        Kakamega
# 11   35          Kericho         Kericho
# 12   22           Kiambu          Kiambu
# 13    3           Kilifi          Kilifi
# 14   20        Kirinyaga  Kerugoya/Kutus
# 15   45            Kisii           Kisii
# 16   42           Kisumu          Kisumu
# 17   15            Kitui           Kitui
# 18    2            Kwale           Kwale
# 19   31         Laikipia        Rumuruti
# 20    5             Lamu            Lamu
# 21   16         Machakos        Machakos
# 22   17          Makueni            Wote
# 23    9          Mandera         Mandera
# 24   10         Marsabit        Marsabit
# 25   12             Meru            Meru
# 26   44           Migori          Migori
# 27    1          Mombasa    Mombasa City
# 28   21         Murang’a        Murang’a
# 29   47          Nairobi    Nairobi City
# 30   32           Nakuru          Nakuru
# 31   29            Nandi        Kapsabet
# 32   33            Narok           Narok
# 33   46          Nyamira         Nyamira
# 34   18        Nyandarua        Ol Kalou
# 35   19            Nyeri           Nyeri
# 36   25          Samburu         Maralal
# 37   41            Siaya           Siaya
# 38    6     Taita-Taveta             Voi
# 39    4       Tana River            Hola
# 40   13    Tharaka-Nithi           Chuka
# 41   26      Trans-Nzoia          Kitale
# 42   23          Turkana          Lodwar
# 43   27      Uasin Gishu         Eldoret
# 44   38           Vihiga          Vihiga
# 45    8            Wajir           Wajir
# 46   24       West Pokot      Kapenguria
#
#                                          Sub-Counties
# 0   Baringo Central, Baringo North, Baringo South,...
# 1   Bomet Central, Bomet East, Chepalungu, Konoin,...
# 2   Bumula, Kabuchai, Kanduyi, Kimilil, Mt Elgon, ...
# 3   Budalangi, Butula, Funyula, Nambele, Teso Nort...
# 4   Keiyo North, Keiyo South, Marakwet East, Marak...
# 5     Manyatta, Mbeere North, Mbeere South, Runyenjes
# 6   Daadab, Fafi, Garissa Township, Hulugho, Ijara...
# 7   Homabay Town, Kabondo, Karachwonyo, Kasipul, M...
# 8                           Isiolo, Merti, Garbatulla
# 9   Isinya, Kajiado Central, Kajiado North, Loitok...
# 10  Butere, Kakamega Central, Kakamega East, Kakam...
# 11  Ainamoi, Belgut, Bureti, Kipkelion East, Kipke...
# 12  Gatundu North, Gatundu South, Githunguri, Juja...
# 13  Ganze, Kaloleni, Kilifi North, Kilifi South, M...
# 14  Kirinyaga Central, Kirinyaga East, Kirinyaga W...
# 15
# 16  Kisumu Central, Kisumu East , Kisumu West, Muh...
# 17  Kitui West, Kitui Central, Kitui Rural, Kitui ...
# 18            Kinango, Lunga Lunga, Msambweni, Matuga
# 19  Laikipia Central, Laikipia East, Laikipia Nort...
# 20                               Lamu East, Lamu West
# 21  Kathiani, Machakos Town, Masinga, Matungulu, M...
# 22  Kaiti, Kibwezi West, Kibwezi East, Kilome, Mak...
# 23  Banissa, Lafey, Mandera East, Mandera North, M...
# 24                  Laisamis, Moyale, North Hor, Saku
# 25  Buuri, Igembe Central, Igembe North, Igembe So...
# 26  Awendo, Kuria East, Kuria West, Mabera, Ntimar...
# 27    Changamwe, Jomvu, Kisauni, Likoni, Mvita, Nyali
# 28  Gatanga, Kahuro, Kandara, Kangema, Kigumo, Kih...
# 29  Dagoretti North, Dagoretti South, Embakasi Cen...
# 30  Bahati, Gilgil, Kuresoi North, Kuresoi South, ...
# 31  Aldai, Chesumei, Emgwen, Mosop, Nandi Hills, T...
# 32  Narok East, Narok North, Narok South, Narok We...
# 33  Borabu, Manga, Masaba North, Nyamira North, Ny...
# 34  Kinangop, Kipipiri, Ndaragwa, Ol-Kalou, Ol Jor...
# 35  Kieni East, Kieni West, Mathira East, Mathira ...
# 36          Samburu East, Samburu North, Samburu West
# 37  Alego Usonga, Bondo, Gem, Rarieda, Ugenya, Unguja
# 38                     Mwatate, Taveta, Voi, Wundanyi
# 39                               Bura, Galole, Garsen
# 40  Tharaka North, Tharaka South, Chuka, Igambango...
# 41     Cherangany, Endebess, Kiminini, Kwanza, Saboti
# 42  Loima, Turkana Central, Turkana East, Turkana ...
# 43     Ainabkoi, Kapseret, Kesses, Moiben, Soy, Turbo
# 44           Emuhaya, Hamisi, Luanda, Sabatia, Vihiga
# 45  Eldas, Tarbaj, Wajir East, Wajir North, Wajir ...
# 46  Central Pokot, North Pokot, Pokot South, West ...

# %%
df.to_csv("CountiesSubCounties.csv", index = False)
